# %%
import pandas as pd
import tushare as ts
df = ts.get_today_all()
df = df.query("high>low*1.1 and changepercent<5 and trade>low*1.03")
print(df)
# Out:
# [Getting data:]############################################################        code  name  changepercent  trade   open   high    low  settlement  \
# 139   603701  德宏股份          1.653  12.30  12.13  13.15  11.93       12.10
# 815   600744  华银电力          1.859   2.74   2.63   2.89   2.58        2.69
# 933   600614  鹏起科技          4.360   3.83   3.64   3.98   3.61        3.67
# 1012  600525  长园集团          4.200   6.45   6.22   6.78   6.15        6.19
# 1198  600284  浦东建设          3.012   5.13   4.98   5.45   4.94        4.98
# 1341  600119  长江投资          2.490   7.82   7.45   8.31   7.45        7.63
# 1364  600095   哈高科          4.145   4.02   3.85   4.25   3.81        3.86
# 1441  300749  顶固集创         -4.498  30.36  33.25  34.77  29.21       31.79
# 1442  300748  金力永磁         -4.876  31.41  36.32  36.32  30.33       33.02
# 1570  300612  宣亚国际          4.189  17.16  16.21  17.81  15.99       16.47
# 1641  300537  广信材料          0.104   9.61   9.45  10.20   9.25        9.60
# ...
