# %%
import tushare as ts

df = ts.inst_tops(10)
df.columns=["股票代码","股票名称","买入数量","买人次数","卖出数量","卖出次数","净额"]
df2 = df.sort_values(by="净额",ascending=False)
df2.to_excel("/home/wangd/机构席位追踪.xlsx")
print(df2)
# Out:
# [Getting data:]###       股票代码  股票名称      买入数量  买人次数      卖出数量  卖出次数        净额
# 0    600845  宝信软件  17788.84     3   5125.10     2  12663.74
# 1    002493  荣盛石化  12150.90     1      0.00     0  12150.90
# 2    300750  宁德时代  13184.13     2   1053.68     1  12130.45
# 3    600739  辽宁成大  12119.20     1      0.00     0  12119.20
# 4    300760  迈瑞医疗  17535.58     2   6459.82     2  11075.76
# 5    002384  东山精密  11751.17     4    685.54     1  11065.63
# 6    603538   美诺华   5448.36     5      0.00     0   5448.36
# 7    600260  凯乐科技   4141.32     1      0.00     0   4141.32
# 8    601588  北辰实业   3183.46     1      0.00     0   3183.46
# 9    300296   利亚德   6567.49     3   4454.51     4   2112.98
# 10   002643  万润股份   3174.73     4   1215.67     1   1959.06
# 11   300009  安科生物   1930.76     4      0.00     0   1930.76
# 12   002419  天虹股份   2471.31     4   1078.33     3   1392.98
# 13   600848  上海临港   1230.40     2      0.00     0   1230.40
# ...
