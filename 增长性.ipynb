# %%
import pandas as pd
import tushare as ts
df = ts.get_report_data(2018,2)
df.columns = ["代码","名称","每股收益","每股收益同比(%)","每股净资产","净资产收益率(%)",
"每股现金流量(元)","净利润(万元)","净利润同比(%)","分配方案","发布日期"]
df = df.sort_values(by="净利润同比(%)",ascending=False)
print(df)
df.to_excel("/home/wangd/增长性.xlsx")
# Out:
# [Getting data:]############################################################          代码     名称  每股收益  每股收益同比(%)  每股净资产  净资产收益率(%)  每股现金流量(元)    净利润(万元)  \
# 591   600387   海越能源  0.49   16100.00    NaN       9.25        NaN   22651.30
# 3258  300308   中际旭创  0.67    3250.00    NaN       7.60        NaN   31690.38
# 3508  000537   广宇发展  0.90    1700.00    NaN      16.03        NaN  166891.97
# 756   601360    三六零  0.23     249.54    NaN       8.55        NaN  153701.40
# 916   300458   全志科技  0.23    4500.00    NaN       3.67        NaN    7545.22
# 3013  600227    圣济堂  0.07    4247.06    NaN       2.71        NaN   12828.68
# 3056  600740   山西焦化  0.75    2781.15    NaN      32.36        NaN   82325.17
# 3364  600569   安阳钢铁  0.43    3441.67    NaN      14.60        NaN  101673.07
# 3351  600569   安阳钢铁  0.43    3441.67    NaN      14.60        NaN  101673.07
# 249   600645   中源协和  0.70    3400.00    NaN      16.67        NaN   27020.76
# ...
