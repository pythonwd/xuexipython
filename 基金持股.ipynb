# %%
import tushare as ts

df = ts.fund_holdings(2018, 2)
df = df.sort_values(by="nlast",ascending=False)
print(df)
df.to_excel("/home/wangd/基金持股.xlsx")
# Out:
# [Getting data:]###########################<urlopen error timed out>
# #        code      name        date nums nlast     count      clast     amount  \
# 1201  002465  东兴众智优选混合  2018-06-30  150    99  27862.27    9108.62  223734.02
# 452   600482      中国动力  2018-06-30  140    99  14068.03    1399.27  245487.19
# 1323  002217       合力泰  2018-06-30  122    99  22711.97    7353.81  187373.74
# 196   601600      中国铝业  2018-06-30  124    99  28175.76   23177.11  108194.93
# 157   601919      中远海控  2018-06-30  111    99   7748.37    4864.46   38121.97
# 843   300244      迪安诊断  2018-06-30  127    99   2429.98    1516.97   46193.84
# 1202  002465      海格通信  2018-06-30  150    99  27862.27    9108.62  223734.02
# 1135  002600      领益智造  2018-06-30  116    98  10374.86   -1257.49   53845.54
# 342   600729      重庆百货  2018-06-30  129    98   3007.75    1259.77   99105.20
# 1040  002892       科力尔  2018-06-30  112    98    122.73     107.33    3674.62
# ...
